# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Create new csv for all month for listings
listings_4_2020 = pd.read_csv('listings_4_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_5_2020 = pd.read_csv('listings_5_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_6_2020 = pd.read_csv('listings_6_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_10_2020 = pd.read_csv('listings_10_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_11_2020 = pd.read_csv('listings_11_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_12_2020 = pd.read_csv('listings_12_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_1_2021 = pd.read_csv('listings_1_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_2_2021 = pd.read_csv('listings_2_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
listings_3_2021 = pd.read_csv('listings_3_21.csv.gz', compression='gzip',
                   error_bad_lines=False)

# %%
listings_merge = [listings_4_2020,
                 listings_5_2020,
                 listings_6_2020,
                 listings_10_2020,
                 listings_11_2020,
                 listings_12_2020,
                 listings_1_2021,
                 listings_2_2021,
                 listings_3_2021]

listings = pd.concat(listings_merge)

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20200428151650   2020-04-29
# 1  11169  https://www.airbnb.com/rooms/11169  20200428151650   2020-04-29
# 2  11945  https://www.airbnb.com/rooms/11945  20200428151650   2020-04-29
# 3  19581  https://www.airbnb.com/rooms/19581  20200428151650   2020-04-28
# 4  22006  https://www.airbnb.com/rooms/22006  20200428151650   2020-04-29
#
#                                                name  \
# 0  SunsplashedSerenity walk to Harvard & Fresh Pond
# 1   Lovely Studio Room: Thu-Mons Near Universities!
# 2                  Near Harvard: Safe & Lovely Room
# 3                          Furnished suite, Windsor
# 4                  B & B near Harvard's Quad Houses
#
#                                              summary  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...
# 1  Large sunny room which comfortably fits a coup...
# ...

# %%
listings.info(108)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7866 entries, 0 to 816
# Data columns (total 108 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    id                                            int64
#  1    listing_url                                   object
#  2    scrape_id                                     int64
#  3    last_scraped                                  object
#  4    name                                          object
#  5    summary                                       object
#  6    space                                         object
#  7    description                                   object
#  8    experiences_offered                           object
#  9    neighborhood_overview                         object
#  10   notes                                         object
#  11   transit                                       object
# ...

# %%
listings['last_review'] = pd.to_datetime(listings['last_review'])
listings = listings[(listings['last_review'] >= '2020-04-01')]
listings
# Out:
#            id                            listing_url       scrape_id  \
# 33    1193862   https://www.airbnb.com/rooms/1193862  20200428151650
# 34    1193875   https://www.airbnb.com/rooms/1193875  20200428151650
# 38    1225831   https://www.airbnb.com/rooms/1225831  20200428151650
# 40    1307195   https://www.airbnb.com/rooms/1307195  20200428151650
# 61    1984737   https://www.airbnb.com/rooms/1984737  20200428151650
# ..        ...                                    ...             ...
# 775  47538101  https://www.airbnb.com/rooms/47538101  20210325145911
# 777  47703691  https://www.airbnb.com/rooms/47703691  20210325145911
# 784  48107460  https://www.airbnb.com/rooms/48107460  20210325145911
# 785  48108594  https://www.airbnb.com/rooms/48108594  20210325145911
# 788  48157277  https://www.airbnb.com/rooms/48157277  20210325145911
#
#     last_scraped                                               name  \
# 33    2020-04-28                          Middle Room in Shared Apt
# ...

# %%
list(listings.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
#checking the nulls for each feature
print(listings.isnull().sum().any())
listings.isnull().sum().sort_values(ascending=False)
# Out:
# True
# neighbourhood_group_cleansed    2125
# xl_picture_url                  2125
# medium_url                      2125
# thumbnail_url                   2125
# square_feet                     2122
#                                 ...
# availability_30                    0
# availability_60                    0
# availability_90                    0
# availability_365                   0
# id                                 0
# Length: 108, dtype: int64

# %%
listings_no_nulls = set(listings.columns[listings.isnull().mean()==0]) 
print(listings_no_nulls)
# Out:
# {'instant_bookable', 'review_scores_checkin', 'has_availability', 'calculated_host_listings_count_shared_rooms', 'property_type', 'longitude', 'review_scores_location', 'listing_url', 'review_scores_rating', 'reviews_per_month', 'name', 'price', 'number_of_reviews', 'picture_url', 'minimum_nights_avg_ntm', 'review_scores_value', 'accommodates', 'minimum_maximum_nights', 'review_scores_cleanliness', 'calendar_last_scraped', 'maximum_maximum_nights', 'last_review', 'calculated_host_listings_count_entire_homes', 'latitude', 'calculated_host_listings_count', 'last_scraped', 'availability_30', 'id', 'host_verifications', 'host_id', 'minimum_minimum_nights', 'amenities', 'number_of_reviews_ltm', 'minimum_nights', 'review_scores_communication', 'maximum_nights_avg_ntm', 'availability_365', 'host_url', 'first_review', 'scrape_id', 'neighbourhood_cleansed', 'availability_60', 'review_scores_accuracy', 'maximum_nights', 'calculated_host_listings_count_private_rooms', 'availability_90', 'room_t
# ...

# %%
def impute_nan_category(listings,host_name):
     listings[host_name] = np.where(listings[host_name].isnull(),"Unknown",listings[host_name])
for Columns in ['host_name']:
    impute_nan_category(listings,Columns)

# %%
listings.isnull().sum()
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# name                                              0
#                                                ...
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                                 0
# bathrooms_text                                  324
# number_of_reviews_l30d                          324
# Length: 108, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2125 entries, 33 to 788
# Columns: 108 entries, id to number_of_reviews_l30d
# dtypes: datetime64[ns](1), float64(24), int64(20), object(63)
# memory usage: 1.8+ MB

# %%
listings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  2.125000e+03  2.125000e+03            0.0         0.0             0.0
# mean   2.349152e+07  2.020523e+13            NaN         NaN             NaN
# std    1.379594e+07  4.620932e+09            NaN         NaN             NaN
# min    8.521000e+03  2.020043e+13            NaN         NaN             NaN
# 25%    1.316994e+07  2.020103e+13            NaN         NaN             NaN
# 50%    2.288803e+07  2.020123e+13            NaN         NaN             NaN
# 75%    3.371950e+07  2.021023e+13            NaN         NaN             NaN
# max    4.815728e+07  2.021033e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  2.125000e+03          2120.000000                2120.000000
# mean   9.126929e+07            38.018396                  38.018396
# std    1.066058e+08           202.907298                 202.907298
# ...

# %%
listings.dtypes.value_counts()
# Out:
# object            63
# float64           24
# int64             20
# datetime64[ns]     1
# dtype: int64

# %%
listings.to_csv('listings.csv', index=False)

# %%
#Create new csv for all month for calendar
calendar_4_2020 = pd.read_csv('calendar_4_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_5_2020 = pd.read_csv('calendar_5_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_6_2020 = pd.read_csv('calendar_6_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_10_2020 = pd.read_csv('calendar_10_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_11_2020 = pd.read_csv('calendar_11_20.csv.gz', compression='gzip',
                   error_bad_lines=False)

calendar_12_2020 = pd.read_csv('calendar_12_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_1_2021 = pd.read_csv('calendar_1_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_2_2021 = pd.read_csv('calendar_2_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
calendar_3_2021 = pd.read_csv('calendar_3_21.csv.gz', compression='gzip',
                   error_bad_lines=False)

# %%
#Check missing values
calendar_4_2020.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    40
# maximum_nights    40
# dtype: int64

# %%
calendar_4_2020.fillna(calendar_4_2020.mean(), inplace=True)
calendar_4_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_5_2020.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    66
# maximum_nights    66
# dtype: int64

# %%
calendar_5_2020.fillna(calendar_5_2020.mean(), inplace=True)
calendar_5_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_6_2020.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    46
# maximum_nights    46
# dtype: int64

# %%
calendar_6_2020.fillna(calendar_6_2020.mean(), inplace=True)
calendar_6_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_10_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_10_2020.fillna(calendar_10_2020.mean(), inplace=True)
calendar_10_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_11_2020.isnull().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price               0
# adjusted_price      0
# minimum_nights    381
# maximum_nights    381
# dtype: int64

# %%
calendar_11_2020.fillna(calendar_11_2020.mean(), inplace=True)
calendar_11_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_12_2020.isnull().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price               0
# adjusted_price      0
# minimum_nights    130
# maximum_nights    130
# dtype: int64

# %%
calendar_12_2020.fillna(calendar_12_2020.mean(), inplace=True)
calendar_12_2020.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_1_2021.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    31
# maximum_nights    31
# dtype: int64

# %%
calendar_1_2021.fillna(calendar_1_2021.mean(), inplace=True)
calendar_1_2021.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_2_2021.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    56
# maximum_nights    56
# dtype: int64

# %%
calendar_2_2021.fillna(calendar_2_2021.mean(), inplace=True)
calendar_2_2021.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_3_2021.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price              0
# adjusted_price     0
# minimum_nights    40
# maximum_nights    40
# dtype: int64

# %%
calendar_3_2021.fillna(calendar_3_2021.mean(), inplace=True)
calendar_3_2021.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar_merge = [calendar_4_2020,
                 calendar_5_2020,
                 calendar_6_2020,
                 calendar_10_2020,
                 calendar_11_2020,
                 calendar_12_2020,
                 calendar_1_2021,
                 calendar_2_2021,
                 calendar_3_2021]

calendar = pd.concat(calendar_merge)

# %%
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0     2692752  2020-04-28         f   $95.00         $95.00             2.0
# 1        8521  2020-04-29         f  $220.00        $220.00             3.0
# 2        8521  2020-04-30         f  $220.00        $220.00             3.0
# 3        8521  2020-05-01         f  $220.00        $220.00             3.0
# 4        8521  2020-05-02         f  $220.00        $220.00             3.0
#
#    maximum_nights
# 0             4.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2871204 entries, 0 to 298244
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 175.2+ MB

# %%
calendar['date'] = pd.to_datetime(calendar['date'])

# %%
calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  2.871204e+06    2.871204e+06    2.871204e+06
# mean   2.359549e+07    6.311910e+01    9.078496e+02
# std    1.451527e+07    1.403835e+02    5.384361e+02
# min    8.521000e+03    1.000000e+00    2.000000e+00
# 25%    1.112721e+07    2.000000e+00    1.124000e+03
# 50%    2.256716e+07    2.100000e+01    1.125000e+03
# 75%    3.669906e+07    9.100000e+01    1.125000e+03
# max    4.882632e+07    7.300000e+02    1.125000e+04

# %%
calendar.dtypes.value_counts()
# Out:
# object            3
# float64           2
# int64             1
# datetime64[ns]    1
# dtype: int64

# %%
calendar.to_csv('calendar.csv', index=False)

# %%
#Create new csv for all month for reviews
reviews_4_2020 = pd.read_csv('reviews_4_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_5_2020 = pd.read_csv('reviews_5_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_6_2020 = pd.read_csv('reviews_6_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_10_2020 = pd.read_csv('reviews_10_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_11_2020 = pd.read_csv('reviews_11_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_12_2020 = pd.read_csv('reviews_12_20.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_1_2021 = pd.read_csv('reviews_1_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_2_2021 = pd.read_csv('reviews_2_21.csv.gz', compression='gzip',
                   error_bad_lines=False)
reviews_3_2021 = pd.read_csv('reviews_3_21.csv.gz', compression='gzip',
                   error_bad_lines=False)

# %%
reviews_merge = [reviews_4_2020,
                 reviews_5_2020,
                 reviews_6_2020,
                 reviews_10_2020,
                 reviews_11_2020,
                 reviews_12_2020,
                 reviews_1_2021,
                 reviews_2_2021,
                 reviews_3_2021]

reviews = pd.concat(reviews_merge)

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        8521      6009  2009-07-23        25629          Mara
# 1        8521      6386  2009-07-30        26357     Stephanie
# 2        8521   6910163  2013-08-30      5747319       Lynette
# 3        8521  37307811  2015-07-06     27670573        Salina
# 4        8521  38475589  2015-07-16     10811805        Benoni
#
#                                             comments
# 0  This is a fabulous apartment!  Great neighborh...
# 1  Wonderful host and hostess, great home, locati...
# 2  We had a delightful 2 week stay in Cambridge. ...
# 3  We had a great time during our short stay in C...
# 4  Janet's place is as beautiful as portrayed. Ni...

# %%
reviews['date'] = pd.to_datetime(reviews['date'])
reviews = reviews[(reviews['date'] >= '2020-04-01')]
reviews
# Out:
#        listing_id         id       date  reviewer_id reviewer_name  \
# 4460      1193862  621542692 2020-04-01    311828181   Abdul-Malik
# 4461      1193862  623029446 2020-04-24     80613198          Amna
# 4625      1193875  621536604 2020-04-01    338157108          Tara
# 5246      1225831  621605392 2020-04-02     78318060          Mary
# 5785      1307195  622121374 2020-04-10    342837713    认证手机用户0077
# ...           ...        ...        ...          ...           ...
# 38900    48107460  735358877 2021-02-28    384320002         Chris
# 38901    48107460  737787496 2021-03-09    302602887       Michael
# 38902    48108594  731994744 2021-02-16     25590954        Rachid
# 38903    48157277  738077507 2021-03-11      6146936     Jeannette
# 38904    48157277  741124738 2021-03-21    334258996     Francesca
#
#                                                 comments
# 4460   Great place located just walking distance to w...
# ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14536 entries, 4460 to 38904
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     14536 non-null  int64
#  1   id             14536 non-null  int64
#  2   date           14536 non-null  datetime64[ns]
#  3   reviewer_id    14536 non-null  int64
#  4   reviewer_name  14536 non-null  object
#  5   comments       14469 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 794.9+ KB

# %%
reviews.isnull().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         67
# dtype: int64

# %%
def impute_nan_category(reviews,comments):
     reviews[comments] = np.where(reviews[comments].isnull(),"Unknown",reviews[comments])
for Columns in ['comments']:
    impute_nan_category(reviews,Columns)

# %%
reviews.isnull().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
reviews.dtypes.value_counts()
# Out:
# int64             3
# object            2
# datetime64[ns]    1
# dtype: int64

# %%
reviews.to_csv('reviews.csv', index=False)
